# %% [markdown]
# <a href="https://colab.research.google.com/github/umslengineering/EENG1108/blob/main/week5part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## String

# %%
my_string = "Python is my favorite programming language!"
my_string
type(my_string)
len(my_string)
# Out:
# 43

# %%
long_story = (
    "Lorem ipsum dolor sit amet, consectetur adipiscing elit."
    "Pellentesque eget tincidunt felis. Ut ac vestibulum est."
    "In sed ipsum sit amet sapien scelerisque bibendum. Sed "
    "sagittis purus eu diam fermentum pellentesque."
)
long_story
# Out:
# 'Lorem ipsum dolor sit amet, consectetur adipiscing elit.Pellentesque eget tincidunt felis. Ut ac vestibulum est.In sed ipsum sit amet sapien scelerisque bibendum. Sed sagittis purus eu diam fermentum pellentesque.'

# %%
x = 'ITH-JFK-ITH'
y = 'ITH'
n=x.count(y)
n
# Out:
# 2

# %%
# Count the number of vowels

A = 'auric umsl morning goldfinger'

n = 0
n = n + A.count('a')
n = n + A.count('e')
n = n + A.count('i')
n = n + A.count('o')
n = n + A.count('u')

print(n)
# Out:
# 9

# %%
s = 'nine one one'

n1 = s.find('one')
n2 = s.find('two')
n3 = s.find(' nine')
print(n1)
print(n2)
print(n3)
# Out:
# 5
# -1
# -1

# %%
string1="ab#$%^&!"
print(string1.upper())
print(string1.lower())
# Out:
# AB#$%^&!
# ab#$%^&!

# %% [markdown]
# ## str.replace

# %%
help(str.replace)
# Out:
# Help on method_descriptor:
#
# replace(self, old, new, /, count=-1) unbound builtins.str method
#     Return a copy with all occurrences of substring old replaced by new.
#
#       count
#         Maximum number of occurrences to replace.
#         -1 (the default value) means replace all occurrences.
#
#     If the optional argument count is given, only the first count occurrences are
#     replaced.

# %% [markdown]
# This will not modify my_string because replace is not done in-place.

# %%
print(my_string)
new_str=my_string.replace("f", "A")
print(my_string, "<--after changes")
print(new_str)
# Out:
# Python is my favorite programming language!
# Python is my favorite programming language! <--after changes
# Python is my Aavorite programming language!

# %% [markdown]
# You have to store the return value of replace instead.

# %%
my_modified_string = my_string.replace("a", "?")
print(my_string)
print(my_modified_string)
# Out:
# Python is my favorite programming language!
# Python is my f?vorite progr?mming l?ngu?ge!

# %% [markdown]
# ##f-strings

# %%
first_name = "John"
last_name = "Doe"
age = 18
print(f"My name is {first_name} {last_name}, you can call me {first_name}.")
print(f"I'm {age} years old.")
# Out:
# My name is John Doe, you can call me John.
# I'm 18 years old.

# %%
print(f"Use '=' to also print the variable name like this: {age=}")
# Out:
# Use '=' to also print the variable name like this: age=18

# %% [markdown]
# ##str.join()

# %%
pandas = "pandas"
numpy = "numpy"
requests = "requests"
## join
cool_python_libs = "-> ".join([pandas,numpy,requests])

print(f"Some cool python libraries: {cool_python_libs}")
# Out:
# Some cool python libraries: pandas-> numpy-> requests

# %% [markdown]
# ##str.upper(), str.lower(), str.title()

# %%
mixed_case = "PyTHoN hackER"
print(mixed_case.upper())
print(mixed_case.lower())
print(mixed_case.title())
# Out:
# PYTHON HACKER
# python hacker
# Python Hacker

# %% [markdown]
# ##str.strip()

# %%
ugly_formatted = " \n \t \t Some story to tell "
stripped = ugly_formatted.strip()

print(f"ugly: {ugly_formatted}")
print(f"stripped: {stripped}")
# Out:
# ugly:
#  	 	 Some story to tell
# stripped: Some story to tell

# %% [markdown]
# ##str.split

# %%
sentence = "three different words"
words = sentence.split()
print(words)
# Out:
# ['three', 'different', 'words']

# %%
type(words)
# Out:
# list

# %%
secret_binary_data = "01001,101101,11100000"
binaries = secret_binary_data.split(",")
print(binaries)
# print(type(binaries))
# Out:
# ['01001', '101101', '11100000']

# %% [markdown]
# ##Calling multiple methods in a row

# %%
ugly_mixed_case = "   ThIS LooKs BAd "
pretty = ugly_mixed_case.strip().lower().replace("bad", "good")
print(pretty)
# Out:
# this looks good

# %% [markdown]
# ##Escape characters

# %%
two_lines = "First line\nSecond line"
print(two_lines)
indented = "\tThis will be indented"
print(indented)
# Out:
# First line
# Second line
# 	This will be indented

# %% [markdown]
# ## Date Format

# %%
s = '9/11/2031'
First = s.find('/')
Second = s.find('/', First + 1)
print(First, Second)

M = s[0:First]
D = s[First + 1:Second]
Y = s[Second + 1:]

print('\nTake apart %s :' % s)
print('   Month = %s, Day = %s , Year = %s' % (M, D, Y))
# Out:
# 1 4
#
# Take apart 9/11/2031 :
#    Month = 9, Day = 11 , Year = 2031

# %%
s = '9/11/2031'
First = s.find('/')
Second = s.find('/', First + 1)

M = s[0:First]
D = s[First + 1:Second]
Y = s[Second + 1:]

print('\nTake apart %s :' % s)
print('   Month = %s, Day = %s , Year = %s' % (M, D, Y))


# Given a date string like '7-Jul-2024' we show how
# the string method replace and the built-in function
# len can be used to create the alternative format
# '7JUL24'

s = '20-Jan-2025'
print('\nWe can rewrite %s as' % s)

# Get rid of the hyphens.
s1=s.replace("-","")

# Get rid of the first two digits in the year.
m=len(s1)
print(s1)
s2=s1[0:m-4] + s1[m-2:]
# s2=s1[0:5] + s1[-2:]

# Convert the month acronym to upper case
s3=s2.upper()

print('   ', s3)
# Out:
# Take apart 9/11/2031 :
#    Month = 9, Day = 11 , Year = 2031
#
# We can rewrite 20-Jan-2025 as
# 20Jan2025
#     20JAN25

# %%
s = '                   Stand Still.                '
print('\n', s)

# Remove the leading blanks and count how many there are.
s1 = s.lstrip()
nLeadingBlanks = len(s) - len(s1)
s = s.replace(" ", ">", nLeadingBlanks)
print(s)

# Remove the trailing blanks and count how many there are.
s2 = s.rstrip()
nTrailingBlanks = len(s) - len(s2)
s = s[:-nTrailingBlanks] + s[-nTrailingBlanks:].replace(' ', '<')
print(s)
# Out:
#                     Stand Still.
# >>>>>>>>>>>>>>>>>>>Stand Still.
# >>>>>>>>>>>>>>>>>>>Stand Still.<<<<<<<<<<<<<<<<

# %% [markdown]
# 	*	s[:-nTrailingBlanks] → everything except the last n spaces
# 	*	s[-nTrailingBlanks:] → just the trailing spaces
# 	*	.replace(' ', '<') → replace spaces in that slice only

# %%
s = 'The Quick Brown Fox Jumped Over The Lazy Dog'
print('\nInput string   =', s)

# Convert everything to lower case and remove the blanks.
s = s.lower()
s = s.replace(' ', '')
print(s)

# Compute the total number of letters and the total number of vowels
numLetters = len(s)
numVowels = s.count("a")+s.count("e")+s.count("i") + s.count("o") + s.count("u")

fraction = float(numVowels) / float(numLetters)

print(f'Vowel fraction = {fraction:5.2f}')
# Out:
# Input string   = The Quick Brown Fox Jumped Over The Lazy Dog
# thequickbrownfoxjumpedoverthelazydog
# Vowel fraction =  0.33
